// %% [markdown]
// <a href="https://colab.research.google.com/github/apham7100/apham.github.io/blob/main/Final_Project_SAA_Final_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %% [markdown]
// # ARE 258 Final Replication Project
// ## Article: Labor Supply and the Value of Non-Work Time: Experimental Estimates from the Field
// ### Author:  Alexandre Mas and Amanda Pallais
// ### Date:    5/27/2022
// ### Team: Sofia, Adreanna, Avetik

// %% [markdown]
// ## Introduction and Motivation
//
//
// **[Q1]** The main motivation for the paper focuses on broadening our understanding of the labor supply relationship and how it impacts the distribution of work hours in the economy. This paper also analyzes the psychological benefits of having a job and of having low values of $z$. **[Q2]** Overall, the authors investigate the marginal value of non-work time and estimates the opportunity cost of unemployed applicants working an additional 5 hours. **[Q3]** Estimating the opportunity cost is difficult, however it allows the authors to estimate how much people value marginal leisure time.
//
// The authors use a field experiment to estimate $Z$ (flow value of non-work time relative to worker's marginal product). **[Q7]** They posted a data entry position online and asked applicants to choose between two job bundles with different weekly hours, increasing 5 hours at a time, and randomly assigned wages. This allows researchers to estimate the Marginal Value of Time (MVT) over h. MVT increases in hours worked and creates the labor supply function.
//
// **[Q8]** $MVT_{i h}$ is the marginal value of non work time for individual "i" with number of hours worked "h". Here the h indicates the job with more hours. An alternative way to interpret $MVT_{i h}$ is the approximation of individual ***i's*** inverse labor supply function between long and short hours.
//
// The paper also focuses on estimating the flow value of non-work time relative to market wage $\tilde z$. This is calculated by combining MVT estimates with predicted market wages.**[Q4]** $Z$ and $\tilde Z$ are different. $z$ measures the flow value of non-work time relative to a worker’s marginal product. A high $z$ follows the trend of the business cycle. $\tilde z$ estimates the flow value of non work time relative to market wage. This measurement takes MVT estimates and combines it with predicted wages.
//
// This paper relates to existing research on reservation wage such as Feldstein and Poterba (1984) and Roulet (2019), but here, the authors measure MVT at different hours of work in a natural environment. This paper also contributes to the existing literature of using field experiments to analyze labor supply relationships. These existing papers include Burtless and Hausman (1978), Angrist et al (2017).

// %% [markdown]
// ## Experimental Design

// %% [markdown]
// **[Q5]** This fascinating 2017 experiment was conducted during the hiring process of telephone interviewer and data entry jobs and used cross-sectional survey data to complete the analysis. **[Q6], [Q7]** The applicants to these jobs are primarily women with varying levels of education from high school to college, and most are in the age range of 26-39. Advertisements for the positions were posted nationally in 80 major cities on a US job search site. The advertisements themselves only indicate the type of work being done and that compensation will be hourly: there is no indication on the advertisements at this time about the number of work hours nor the wage, and does not specify the job is remote.
//
// The application was linked through the ad to an external website, where applicants first created an account and filled out a demographic questionnaire. Applicants were then shown two descriptions of job positions which differed only in the numbers of hourly work, and hourly wage. Job seekers were then asked to choose one of the two jobs to apply to. The framing of the two position descriptions were as follows:
//
// *This is a one-month work-from-home [type] position.
// The position is [X] hours per week.
// This position pays [Y] dollars per hour*
//
// *This is a one-month work-from-home [type] position.
// The position is [X+5] hours per week.
// This position pays [Z] dollars per hour*
//
// Where [type] is the position type (telephone interviewer or data entry work), and [Y] and [Z] are dollar amounts. Each applicant was shown either both data entry positions or both phone survey positions.
//
// The additional earnings an applicant would receive from working the longer job instead of the shorter job were randomly varied. **[Q10]** The authors then take this opportunity to define the effective wage as $e_{ih} = \frac{h_i x w_{ih} - (h_i - 5)x w_{ih-5}}{5}$.
//
// The authors randomly select $e_{ih} \in$ {0,4,8,12,16,18,20,24,28}. For the three lowest choices of $h$ (5 vs. 10, 10 vs. 15, and 15 vs. 20), the authors also let $e_{ih}$ take the values of {2,6,10}. This is because piloting showed the workers' values of time were lower at these hours levels and including them could lead to less extrapolation.
//
// The authors forge on to mention that the randomly-chosen effective wage determined both jobs' hourly wage. **[Q10]** That is, the higher hourly job wage always paid 18 dollars/hr, and the other hourly wage was determined using the equation above. For example, if a 25-hour job paid $18/hr, then the 30-hour job would pay 15 dollars/hr such that wages were equivalent.
//
// **[Q11]** The authors then use these values of $e_{ih}$ to calculate $MVT_{ih}$ and therefore $\overline{MVT_h}$. **[Q9]** $\overline{MVT_{h}}$ is the average marginal hourly value of time in the sample. $\overline{MVT_{h}}$ is the expectation of $MVT_{ih}$. This allows us to estimate the value of one more hour of work on average to everyone included in the sample. The estimates of $\overline{MVT_{h}}$ are then combined for different hours levels up to 40 hours per week to form the estimate of $\tilde{z}$.
//
// $$\tilde{z} = \frac{1}{\hat{w}} [\frac{5(\overline{MVT_{5}} + \overline{MVT_{10}} + . . . + \overline{MVT_{40}}}{40}]$$
//
// **[Q12]**  Where $\hat{w}$ is average predicted pretax hourly market wage, calculated using gender, race, education, and other data in the applicants' five-year age bin from the 2016 CPS MORGs survey. For unemployed applicants, the resulting wage is discounted by 6%, which is the estimated wage penalty employed hourly workers who separated from their job in the last 3 years.  The authors also use the CPS MORGs survey data to calculate $\hat{w}$,the average predicted pretax hourly market wage.
//
// The authors also offered positions with overtime, which is greater than 40 hrs per week. The FLSA requires 1.5 times the regular wage in compensation per hour of overtime worked (the specifications of how this differs from hourly wage is discussed in "Estimation" section). Thus, for randomly selected participants, the following descriptions were shown:
//
// *This is a one-month work-from-home [type] position.
// The position is 40 hours per week.
// This position pays $18 per hour.*
//
// Then, for 45 and 50 hour positions:
//
// *This is a one-month work-from-home [type] position.
// The position is [45/50] hours per week.
// This position pays $18 per hour for the first 40 hours and [EW] dollars per hour for the remaining [5/10] hours.*
//
// Where EW is the effective wage. The authors randomly select EW $\in$ {27,29,31,33,35}.
//
// Due to concerns that it may be easier for applicants to make choices only when marginal wages differ than when average wages differ where they must determine effective wages, a validation study assessed whether applicants make similar decisions when choices are over marginal vs. average wages. Similar results were found between the two.

// %% [markdown]
// ## II Conceptual and Econometric framework

// %% [markdown]
// ### Conceptual framework

// %% [markdown]
// Following the experimental design, applicants are shown a shorter and a longer job with hours and wages are given by $\left\{h_{i}-5, w_{i h-5}\right\}$ and $\left\{h_{i}, w_{i h}\right\}$, respectively.
// The key concept is the $M V T_{i h}$ which is mean hourly value of time between $h-5$ and $h$ weekly hours of work for each individual $i$.
// Authors present $M V T_{i h}$ as an approximation to $i$ 's inverse labor supply function between $h_{i}-5$ and $h_{i}$ hours relying on the theoretical concepts that work hours should be equal to the wage with the shadow value of time (Becker 1965; Gronau 1977; Heckman 1974). This means that $w_{i}\left(h_{i}-5\right)$ $<M V T_{i h}<w_{i}\left(h_{i}\right)$ if an individual's inverse labor supply function, $w_{i}(\cdot)$, is strictly increasing.
// In other words one would choose to work strictly between $h_{i}-5$ and $h_{i}$ hours per week at a wage of $M V T_{i h}$.
//
//
// The explicit assumption on the individual choices is provided: one would choose the longer job if the money she earns from working the additional five hours $\left(5 e_{i h}\right)$ exceeds the cost of working these additional hours $\left(5 M V T_{i h}\right)$. That is, if $M V T_{i h}<e_{i h}$.  **[Q9]** Hence, following these conceptual framework authors estimate the average marginal value of time ,  $\overline{M V T_{h}}=E\left[M V T_{i h}\right]$ by using applicants' choices over the $h$ and $h-5$ hour. After that they form $\tilde{z}$ estimate, the average flow value of non-work time, by combining estimates of $\overline{M V T_{h}}$ for different hours levels up to 40 hours per week to .

// %% [markdown]
// ### Econometric framework and Estimation

// %% [markdown]
// **[Q11]** Assuming a logistic distribution for $M V T_{i h}$ authors estimate the probability of choosing the longer job $\operatorname{Pr}\left(\textbf{1}\left[h_{i}\right]=1 \mid e_{i h}\right)=\operatorname{Pr}\left(M V T_{i h}<e_{i h} \mid e_{i h}\right)$ by using a logit model for which the dependent variable is the indicator for choosing the longer position $\left(\mathbf{1}\left[h_{i}\right]\right)$ and the the explanatory variable is the effective wage $\left(e_{i h}\right)$.

// %% [markdown]
// **[Q11]** Since according to FLSA high effective wages should be higher for overtime workers, 1.5 times the hourly wage, authors modified the estimation procedure of $\overline{M V T_{h}}$ for the overtime treatments. They use extrapolated $\overline{M V T_{h}}$ using the estimates of intercept in the non-overtime treatments. This procedure requires to do following two initial steps:
//
// 1. For each hour less than 40, run logit model regression as described above,
// 2. Calculate Intercept for each hour category and create a new variable called "intercept" with total 7 non-missing observations (corresponding to the 7 unique hour categories)

// %%
use experiment.dta if emp_emp == 0 & chose_long < ., clear
qui{
    gen intercept = .
egen tag = tag(hours_high)
foreach hrs in 10 15 20 25 30 35 40 {
logit chose_long effectivewage if hours_high == `hrs'                         // 1
    
    
replace intercept = (1/(1+exp(-_b[_cons]))) if tag == 1 & hours_high == `hrs' // 2
}
}

// %% [markdown]
// From the second step above we can see that the constraint $\operatorname{Pr}\left(\mathbf{1}\left[h_{i}\right]=1 \mid e_{i h}=0\right)$ is used for estimated intercepts. The reason why the authors use this technique is because it increases the precision in the 40 vs. 45-hour choice dramatically. (It has little effect on the estimates for the 45 vs. 50-hour choice where there is less extrapolation.)

// %% [markdown]
// Authors use estimated intercepts at lower hour treatments to predict the intercept as a function of $h$. Hence, the next part is to predict and define intercept constraint for overtime treatments, based on the estimation from previous part, by following the listed steps:
//
// 3. Create new variable called `hours` by taking averages of $h-5$ and $h$

// %%
gen hours=hours_high - 2.5                    // 3

// %% [markdown]
// 4. Run linear probability model on the estimated `intercept` at lower hour treatments (h < 40) to predict the intercept as a function of $h$

// %%
qui reg intercept hours if hours <= 40 & tag == 1     // 4
predict p1
// Out:
// (option xb assumed; fitted values)

// %% [markdown]
// 5. Predict intercept for 45 and 50 hours based on mean value of predicted intercepts and define constraints for those categories.

// %%
qui {
sum p1 if hours == 42.5                           // 5
global int_p1con45 = -ln(1/`r(mean)' - 1)
sum p1 if hours == 47.5
global int_p1con50 = -ln(1/`r(mean)' - 1)
constraint define 45 [_cons] = $int_p1con45
constraint define 50 [_cons] = $int_p1con50
    
    preserve // Need this for appendix Figure 6 
sum p1 if hours == 37.5
global int_p1con40 = -ln(1/`r(mean)' - 1)
constraint define 40 [_cons] = $int_p1con40
    restore
    }

// %% [markdown]
// Looking at the different methods of picking the intercept constraints provided in the Online Appendix, one can see that they give similar estimates. At the same time, authors argue that these adjustments do not affect estimates of $\tilde{z}$.

// %% [markdown]
// Using the constraints from the previous part, the logit model can be run for all categories (step 6). Additionally, we may keep the report format of authors where the matrix is used to construct the final table. **[Q11]** The code-chunk below runs 9 total logit models (for each hours category) and simultaneously, inputs the coefficients and number of observations into the matrix named `mvt` (step 7).

// %%
qui{
mat mvt = J(30,6,.)
global allregs = ""
local row = 1
                                                // 6
foreach hrs in 10 15 20 25 30 35 40 45 50 {          
if `hrs' <= 40              logit chose_long effectivewage if hours_high == `hrs'
if inlist(`hrs',45,50)      logit chose_long effectivewage if hours_high == `hrs', const(`hrs') 
eststo lgt`hrs'
global allregs = "$allregs lgt`hrs'" //necessary for the next chunk 
    
//mat mvt[`row',1] = `hrs'                        // 7                                             
mat mvt[`row',3] = e(N)
local row = `row' + 3
}
}

// %% [markdown]
// **[Q17]** The final estimate of $\overline{M V T_{h}}$ is $-1$ times the estimated intercept divided by the slope coefficient. To illustrate this by an example we can assume $MTV_{ih}$ has mean $\mu$ and variance $s^{2}\pi/3$, where $s$ is the scale parameter. Recall the probability of choosing the longer job in logit model is defined by following formula :
//
// $$Pr(\textbf{1}[h_i] = 1) = Pr(MTV_{ih} < e_{ih}) = Pr(\frac{MTV_{ih}-\mu}{s}) = \Lambda(\frac{1}{s} e_{ih} - \frac{\mu}{s}) = \Lambda(\beta_1 e + \beta_0) = \frac{1}{1+e^{(\beta_1 e + \beta_0)}}$$
//
// where $\Lambda(\cdotp)$ is the standard logistic function. Thus, the slope coefficient of the logistic function, $\beta_1$ is the inverse of the scale parameter and the intercept is $\beta_0 = -\frac{\mu}{s}$. This is reassuring, because the logit cdf is 0.5 when $e=-\frac{\beta_{0} }{ \beta_{1}}$ which is when $e=\mu$, the mean of $MTV_{ih}$.
//
// 8. After running the regression for each hours choice (described in the previous chunk), **[Q13]** they combine the parameter estimates and covariance matrices from all hours choices and calculate robust standard errors on MVT using the delta method. The code-chunk below shows the described procedure where `nlcom` command is used after estimation by the `suest` command to calculate standard errors according to the delta method.

// %%
qui{
    suest $allregs , vce(robust)                                  // 8      
    local row = 1
    foreach hrs in 10 15 20 25 30 35 40 45 50 {
    nlcom  (- [lgt`hrs'_chose_long]_cons / [lgt`hrs'_chose_long]effectivewage)
        
mat v = r(V)
mat mvt[`row',2] = r(b)
mat mvt[`row'+1,2] = v[1,1]^.5
local row = `row' + 3
local w`hrs' = "(- [lgt`hrs'_chose_long]_cons / [lgt`hrs'_chose_long]effectivewage)"

preserve // we need the following part for Fig 1
        collapse chose_long, by(hours_high effectivewage)
tempfile points
save `points'
restore
}
}

// %% [markdown]
// Having estimates of $\overline{M V T_{h}}$, the average value of time between $h-5$ and $h$ hours, for different values of $0 < h <40 $ , authors calculate $\tilde{z}$ (the average flow value of non-work time for a 40-hour job) dividing the per hour $\overline{MVT}$ by the average predicted pretax hourly market wage $\hat{w}$. However, to be able to estimate $\tilde{z}$, authors needed to estimate $\hat{w}$ and marginal value of time for zero to five hours $\overline{M V T_{5}}$.
//
// 9. The pretax hourly market wage $\hat{w}$ is predicted using applicant gender, race, education, age, and data from the 2016 Current Population Survey Merged Outgoing Rotation Groups (CPS MORGs). We provided more detailed discussion about the  $\hat{w}$ in "Experimentla design" section.

// %%
 global basewage = 13.92733                           // 9

// %% [markdown]
// 10. Authors use linear prediction determined by $\overline{M V T_{10}}$ and $\overline{M V T_{15}}$ to predict $\overline{M V T_{5}}$ as no applicants were given zero to five hours choice.

// %%
    local w5 = "((`w15' - `w10')/(12.5-7.5))*(2.5-7.5) + `w10'"    // 10

// %% [markdown]
// 11. **[Q13]** The delta method was used for $\tilde{z}$ estimates calculated by the following equation:
// $$
// \tilde{z}=\frac{1}{\hat{w}}\left[\frac{5\left(\overline{M V T_{5}}+\overline{M V T_{10}}+\cdots+\overline{M V T_{40}}\right)}{40}\right]
// $$

// %%
 qui {  
     nlcom 5*(`w5' + `w10' + `w15' + `w20' + `w25' + `w30' + `w35' + `w40')/40/$basewage      // 11
  
mat v = r(V)
mat mvt[28,2] = r(b)
mat mvt[28,3] = r(N)
mat mvt[29,2] = v[1,1]^.5


}

// %% [markdown]
// Authors present the estimates based on the weighted data. The code-chunk below runs almost the same the procedure to get the weighted estimates. Compared to the unweighted part two important differences need to be mentioned:
// 1. the  $\hat{w}$ used in calculation of $\tilde{z}$ is equal to 15.54637
// 2. Estimation is conducted using `[pw=wgt]`  option to get the weighted indicators.

// %%
qui {
    use experiment.dta, clear
tempfile expdta
save `expdta'
keep if emp_emp == 0
    
    
global basewage = 15.54637                             // 1 
    
gen intercept = .
egen tag = tag(hours_high)
foreach hrs in 10 15 20 25 30 35 40 {
logit chose_long effectivewage if hours_high == `hrs' [pw=wgt]
replace intercept = (1/(1+exp(-_b[_cons]))) if tag == 1 & hours_high == `hrs'
    }
gen hours=hours_high - 2.5
reg intercept hours if hours <= 40 & tag == 1
predict p1
sum p1 if hours == 42.5
global wgt_p1con45 = -ln(1/`r(mean)' - 1)
sum p1 if hours == 47.5
global wgt_p1con50 = -ln(1/`r(mean)' - 1)
constraint define 45 [_cons] = $wgt_p1con45
constraint define 50 [_cons] = $wgt_p1con50
    
    
foreach h in 10 15 20 25 30 35 40 45 50 {
gen hh`h' = (hours_high == `h') if hours_high < .
gen ewage`h' = effectivewage*hh`h' if hours_high < .
}
constraint define 1 [hh45] = ${wgt_p1con45}
constraint define 2 [hh50] = ${wgt_p1con50}

    
    
logit chose_long hh* ewage* [pw=wgt], nocons const(1 2) vce(robust)      // 2

local row = 1
foreach h in 10 15 20 25 30 35 40 45 50 {
// mat mvt[`row',1] = `h'
qui count if hours_high == `h' & ewage`h' < . & wgt < . & chose_long < .
mat mvt[`row',6] = r(N)

nlcom -(_b[hh`h']/_b[ewage`h'])
mat v = r(V)
mat mvt[`row',5] = r(b) 
mat mvt[`row'+1, 5] = v[1,1]^.5

local row = `row'+3
local w`h' = "(-_b[hh`h']/_b[ewage`h'])"
}

local w5 = "((`w15' - `w10')/(12.5-7.5))*(2.5-7.5) + `w10'"
nlcom 5*(`w5' + `w10' + `w15' + `w20' + `w25' + `w30' + `w35' + `w40')/40/$basewage
mat v = r(V)

mat mvt[28,5] = r(b)
mat mvt[28,6] = r(N)
mat mvt[29,5] = v[1,1]^.5
  }

// %%
qui {
    mat def Table1=mvt
    local row = "5___vs___10 . . 10___vs___15 . . 15___vs___20 . . 20___vs___25 . . 25___vs___30 . . 30___vs___35 . . 35___vs___40 . . 40___vs___45 . . 45___vs___50 . . Implied_z . ."
local col = " [Panel_A  Mean_unw Obs_unw] [Panel_B  Mean_w Obs_w]"
mat rownames  Table1= `row'
mat colnames Table1 = `col'
}

// %% [markdown]
// # III Results
//
// ## Descriptive Statistics
// **[Q5]** The authors leverage ***cross sectional survey data*** conducted by the Understanding America Study. The characteristics of the sample include:
//   - 83% female
//   - Average age of 34
//   - Education ranging from a high school and college degrees to no degree
//   - People unemployed for less than 3 months

// %% [markdown]
// **[Q14]** In the ***Online Appendix Table 3***, they regress six characteristics of applicants on indicators for randomly assigned effective wage dummies. This regression is run for each number-of-hours choice. Effective wage indicators are found to be jointly significant only in four regressions.
// - White applicants who chose 40 vs. 45 hrs had a p-value of just 0.02.
// - Black applicants who chose 30 vs. 35 hrs had a p-value of just 0.01.
// - Hispanic applicants who chose 25 vs. 30 hrs had a p-value of just 0.03.
// - Other race applicants who chose 40 vs. 45 hrs had a p-value of 0.01.
//
// It is mentioned in the paper that these 4 statistically significant results out of 54 regressions are likely due to chance, and should not cause concern that randomization was failed. **[Q14]** **To protect respondent confidentiality, authors don't share the variables necessary to replicate Appendix Table 3**

// %% [markdown]
// ***Online Appendix Table 4*** regresses demographic indicators on workers in each hour choice. This table shows  that workers in each hour choice share similar characteristics. For example, a majority of white applicants work in the "5 vs 10" hour choice and a majority of Black applicants work in the "45 vs 50" hour choice. A majority of people in both of those hour choices also have "Some College,  No Degree", are overwhelmingly female, and are in their early to mid 30s.

// %% [markdown]
// The code below follows the same steps and finds similar outputs to the author. The interpretation remains the same and workers in each hour choice share similar characteristics.

// %%
qui {
    clear
tempfile all
save `all', emptyok
foreach cov in gender age education race { 
use experiment_`cov' if emp_emp == 0
append using `all'
save `all', replace
}
}
version 16: table hours_high, c(mean age n age mean female n female)
version 16: table hours_high, c(mean race_white mean race_black mean race_hisp mean race_other n race_white)
version 16: table hours_high, c(mean ed_lessthanhs mean ed_highschool mean ed_somecollege mean ed_collegedeg mean ed_morethancol)
version 16: table hours_high, c(n ed_lessthanhs)
// Out:
// . version 16: table hours_high, c(mean age n age mean female n female)
//
// ------------------------------------------------------------------
// Hours of  |
// longer    |
// job       |    mean(age)        N(age)  mean(female)     N(female)
// ----------+-------------------------------------------------------
//        10 |     31.85345           116      .8673469            98
//        15 |     31.84298           121      .8076923           104
//        20 |     32.16667           126      .8482143           112
//        25 |     33.20667           150      .7692308           130
//        30 |     31.85075           134      .8534483           116
//        35 |     32.66412           131      .8181818           110
//        40 |     30.99074           108      .8478261            92
//        45 |     33.85833           120      .8383839            99
//        50 |     35.26563           128      .8411215           107
// ...

// %% [markdown]
// The code-chunk below provides the p-value from a test of whether the means across hours choices are equal (final column of table 4 in online appendix). As we can see, almost all of them are statistically insignificant at 5% supporting the argument that sample design is balanced.

// %%
foreach y in age female race_white race_black race_hisp race_other ///
ed_lessthanhs ed_highschool ed_somecollege ed_collegedeg ed_morethancol {
qui reg `y' i.hours_high
di "`y': 0" Ftail(e(df_m),e(df_r),e(F))
}
// Out:
// age: 0.09680545
// female: 0.65758566
// race_white: 0.31094554
// race_black: 0.48308592
// race_hisp: 0.35301523
// race_other: 0.9051097
// ed_lessthanhs: 0.69983995
// ed_highschool: 0.18980137
// ed_somecollege: 0.1430245
// ed_collegedeg: 0.02741465
// ed_morethancol: 0.14750374

// %% [markdown]
// ***Appendix Figure 3 and 4*** plots the estimates from regressing an indicator for choosing a job and submitting demographic information on effective wages. These figures argue that the probability of choosing a bundle and the probability of following through on the application after this choice while also entering their demographic information is unrelated to effective wages. ***The variables are appropriately randomized and show no signs of endogeneity***.

// %% [markdown]
// The code below plots the estimates for figure 3 and 4. We regress if the applicant chooses a job on effective wages and if the applicant submits demographic information on effective wages. There was a slight issue when we regressed choseajob on ***wage1-wage25 wage26-wage39***. This image places the horizontal axis of 0 above the coefficient points. However, when we limit the wage to ***wage1-wage24 wage 26-wage39***, we find the same figure and interpretation as the authors. However, this method only excludes one variable so the general interpretation should remain valid. Our codes shows that the variables are appropriately randomized and show no signs of endogeneity.

// %%
//ssc install coefplot
use experiment.dta if dropout_before_exp == 0, clear
qui {
    cap gr drop Fig3 Fig4
gen choseajob = chose_long < . 
tab effectivewage, gen(waged)

* App Fig 3
reg choseajob waged1-waged24  waged26-waged39,r

coefplot , vertical yline(0, lcolor(maroon)) title("Appendix Figure 3. Probability of Choosing" "a Job Option by Effective Wage", size(medlarge)) ///
subtitle("All Experiment Applicants")  bgcolor(white) ylab(-.5(.25)1, labsize(3)) xlab(,labsize(2.5) angle(90)) ///
ytitle("Coefficient") xtitle("Effective Wage") coeflabels(_cons = "Constant") graphregion(color(white)) name(Fig3)
* App Fig 4
    reg submitted_demogs waged1-waged24  waged26-waged39, r

coefplot, yline(0, lcolor(maroon)) title("Appendix Figure 4. Probability of Submitting Subsequent" "Demographic Information by Effective Wage", size(medlarge)) vertical ///
subtitle("All Experiment Applicants")  bgcolor(white) ylab(-.5(.25)1, labsize(3)) xlab(,labsize(2.5) angle(90)) ///
ytitle("Coefficient") xtitle("Effective Wage") coeflabels(_cons = "Constant") graphregion(color(white)) name(Fig4)

}
// Out:
// This front-end cannot display the desired image type.
// This front-end cannot display the desired image type.

// %% [markdown]
// ## Main Treatments
// The authors first visually summarize the data parametrically and non-parametrically. **[Q15]** **Non-parametric methods** do not require any assumptions regarding the pdf or distribution of the data. This methods is usually a weaker statistical procedure and require a larger sample size to offset this effect. On the other hand, **parametric methods** always hinge on pdf assumptions of the population and sometimes rely on a normality assumption (or, in this paper, logistic distribution). That is, they present actual values with the fitted line of logit model.
//
// In ***Figure 1***, the authors create a scatterplot of the share of applicants who chose longer hours against effective wages for each hour choice. A logit MLE is also utilized to constrain the probabilities between zero and one and creates a cdf of the MVT distribution. **[Q16]** The figures illustrate that individuals only choose to work more hours if the wage is higher. There is a positive relationship between hours worked and effective wages. That is, taking into account their opportunity cost, people rationally require higher effective wage for more time spent.

// %% [markdown]
// The code below generates variables for high hours, effective wage. Logit MLE is applied and we generate the `logitp` for each high hour. We then plot the share of applicants choosing longer hours across effective wage. Our figures exactly match that of the authors'. The interpretation remains the same.

// %%
qui {
clear
set obs 9
gen hours_high = _n*5 + 5
expand 100
gen effectivewage = runiform(-.2,35)
gen logitp = .
foreach hh in 10 15 20 25 30 35 40 45 50 {
estimates restore lgt`hh'
predict a
replace logitp = a if hours == `hh'
drop a
}

append using `points', gen(points)

label define hrslab 10 "5 vs. 10 Hours" 15 "10 vs. 15 Hours" 20 "15 vs. 20 Hours" ///
25 "20 vs. 25 Hours" 30 "25 vs. 30 Hours" 35 "30 vs. 35 Hours" 40 "35 vs. 40 Hours" ///
45 "40 vs. 45 Hours" 50 "45 vs. 50 Hours"
label values hours_high hrslab

twoway (scatter chose_long effectivewage if points == 1, symbol(o) color(navy)) ///
(line logitp effectivewage if points == 0, sort color(navy) ///
ylabel(0(.5)1, labsize(small)) ymtick(0(.25)1, grid gmin gmax) xlabel(0(10)35, labsize(small)) xmtick(5(10)35) ///
subtitle(,fcolor(none) nobox) ///
ytitle(Share Choosing Longer Job) xtitle("Effective Wage")), ///
by(hours_high, graphregion(color(white)) ///
title(Figure 1. Marginal Value of Time) subtitle(Unemployed Applicants) legend(off) ///
yrescale xrescale note(`" "'))
}
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// ***Panel A Table 1*** illustrates the unweighted MVT of unemployed applicants. It shows that MVT increases linearly from 5 to 40 working hours chosen. MVT peaks at 15 dollars between 30 to 40 hours worked. MVT sharply increases after 40 hours and peaks around 22 dollars between 40 to 45 hours worked. Overall, within the 30 to 40 hour working range, MVT is equivalent to the average estimated market wage. This argues that the average unemployed applicant will choose to work full time at their expected market wage.

// %% [markdown]
// The authors verify if their results can be applied to the public, outside of their sample.
// 1. The demographic of workers is weighted to match the CPS. These weighted results are similar to non-work time estimates: 0.57
// 2. The results are replicated using UAS online surveys. The applicants choose between hour bundles with randomized wages. Here, the $\tilde z$ = 0.61. This is very similar to the $\tilde z$ value in the original study.
//
// Overall, the author's results are relevant to the general public.

// %% [markdown]
// With the code below we call the matrix we used in "Conceptual framework" section to store the unweighted and weighted mean MVT values across hours worked . **[Q6]** The number of observations for each category are reported next to the mean MVT in the table below. The values found match the authors'.

// %%
mat li Table1
// Out:
// Table1[30,6]
//                [Panel_A   Mean_unw   Obs_unw]   [Panel_B     Mean_w     Obs_w]
//  5___vs___10          .  4.7975992        117          .  5.8837059         94
//            .          .  .95697736          .          .  1.1470742          .
//            .          .          .          .          .          .          .
// 10___vs___15          .  5.2672587        124          .  6.9972183         99
//            .          .  1.2154324          .          .  1.1397669          .
//            .          .          .          .          .          .          .
// 15___vs___20          .  7.0034945        128          .  5.0868282        108
//            .          .  1.9094226          .          .   6.559254          .
//            .          .          .          .          .          .          .
// 20___vs___25          .   8.949075        153          .  8.3012831        125
//            .          .  1.7378816          .          .  3.4357948          .
// ...

// %% [markdown]
// ***Panel B Table 1*** illustrates the weighted MVT of Unemployed Applicants. The authors calculate weights using the DiNardo, Fortin, and Lemieux (1996) method and match the covariate distribution of working applicant ages to the 2016 CPS MORGs. Once the weights are matched to the CPS MORG, the observations are constrained to unemployed applicants. These results have a similar interpretation to Panel A Table 1.

// %% [markdown]
// The authors verify that the framing of bundled choices is uncorrelated with estimated MVTS in the ***Online Appendix Figure 6***. The figure graphs effective wage against the share of applicants choosing a longer job for traditional framing and overtime framing. The values are very similar, so the researchers can rule out the possibility that framing impacts MVT.

// %% [markdown]
// The code below   reframes the `effectivewage` and `ot_treatment` variables. We then run a logit regression of applicants who chose longer hours on effective wages, conditional on whether the treatment is framed traditionally or non-traditionally. The values for traditional and overtime framing are plotted on a twoway scatter. The figure matches what the authors find.

// %%
* Online Appendix Figure 6

qui {
use otvalidation.dta, clear
gen old = 1
set obs 1000
replace effectivewage = runiform(0,20) if effectivewage == . & old == .
replace ot_treatment = rbinomial(1,.5) if ot_treatment == . & old == .
logit chose_long effectivewage if ot_treatment == 0
predict a
logit chose_long effectivewage if ot_treatment == 1, constraint(40)
predict b

bys effectivewage ot_treatment: egen mean_choselong = mean(chose_long)

twoway (scatter mean_choselong effectivewage if ot_treatment == 0, color(maroon)) (line a effectivewage, sort color(maroon)) ///
(scatter mean_choselong effectivewage if ot_treatment == 1, color(navy)) (line b effectivewage, sort color(navy)), ///
graphregion(color(white)) title("Appendix Figure 6. Framing Comparison") ///
subtitle("35 vs. 40 Hours") ylabel(0(.2)1) xlabel(0(5)20)  bgcolor(white) ///
xtitle("Effective Wage") ytitle("Share Choosing Longer Job") ///
legend(label(1 Traditional Framing) label(3 Overtime Framing) order(1 3))
    }
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// ***Figure 2*** illustrates the estimated labor supply curve for estimated values and quartic fit. This line slopes upward and indicates that MVT increases with hours per week, which aligns with the authors' discussion of the findings.

// %% [markdown]
// The code below genereates variables for high work hours and MVT in dollars for each hour chosen. This is then overlaid by quartic polynomials generated from the MVT points. The values are plotted and match the authors' figure 2.

// %%
*figure 2
qui {
    clear
set obs 9
gen hours_high = _n*5 + 5
gen mvtp50 = .
foreach hh in 10 15 20 25 30 35 40 45 50 {
estimates restore lgt`hh'
replace mvtp50 = -(ln(((100-50)/100)/(50/100)) + _b[_cons])/_b[effectivewage] if hours == `hh'
}

gen hrs = hours_high - 2.5
gen hrs2 = hrs^2
gen hrs3 = hrs^3
gen hrs4 = hrs^4
reg mvtp50 hrs*
predict quarticfit

keep mvtp50 hrs
tempfile meanmvt
save `meanmvt'

clear
set obs 1000
gen hrs = runiform(0,50)
gen hrs2 = hrs^2
gen hrs3 = hrs^3
gen hrs4 = hrs^4
predict quarticfit

append using `meanmvt', gen(points)

twoway (scatter mvtp50 hrs if points==1, color(navy)) ///
(line quarticfit hrs if points == 0, sort color(maroon)), graphregion(color(white)) ///
xtitle(Hours per Week) ytitle("Marginal Value of Time (Dollars)")
}
// Out:
// This front-end cannot display the desired image type.

// %% [markdown]
// **Table 2** in the paper illustrates the labor supply elasticities conditional on hours chosen.
//
// Instead of using the provided code, we used previously saved matrices to construct table 2. As a first step, we need to clear the environment. Then we create new database for which variable names are columns from table 1 and observations are the MVT for each hour range provided in table 1.

// %%
* Table 2_part 1
qui {
    clear
svmat mvt, name(col)
}
// Out:
// --more--

// %% [markdown]
// After that,  we keep only observations and variables we need for future calculations.

// %%
* Table 2_part 2
qui {
drop if c3 ==. 
keep c2 
rename c2 mvt
 gen hours=5*mod(_n-1,10) + 5
drop if  hours>45
replace hours = hours+2.5
}

// %% [markdown]
// Using our new databas,e we calculate elasticities. Hence, we get the first column where elasticities are calculated using the mean MVT at each hours choice from the experiment.

// %%
* Table 2_part 3
qui {
    gen dhours = (hours[_n+1] - hours)/((hours[_n+1]+hours)/2)
gen dwage = (mvt[_n+1] - mvt)/((mvt[_n+1]+mvt)/2)
gen elast = dhours/dwage
}

// %% [markdown]
// Authors also calculate elasticities using quadratic, cubic, and quartic transformations of hours.

// %%
* Table 2_part 4
qui {
 gen hours2 = hours^2
 gen hours3 = hours^3
 gen hours4 = hours^4
 reg mvt hours hours2 hours3 hours4
 predict quartic
 gen dwage_quartic = (quartic[_n+1] - quartic)/((quartic[_n+1]+quartic)/2)
 gen elast_quartic = dhours/dwage_quartic
replace hours = hours+2.5
drop if hours==50
 rename elast Raw_points
 rename elast_quartic Quartic_fit 
    }
list hours Raw_points Quartic_fit
// Out:
// . list hours Raw_points Quartic_fit
//
//      +------------------------------+
//      | hours   Raw_poi~s   Quarti~t |
//      |------------------------------|
//   1. |    10    5.357531   1.798559 |
//   2. |    15    1.177908   2.468283 |
//   3. |    20    1.024923   1.785927 |
//   4. |    25   -1.721775   1.034779 |
//   5. |    30    .2809871   .7051659 |
//      |------------------------------|
//   6. |    35   -.7100567   .5815201 |
//   7. |    40    .2142128   .5578871 |
//   8. |    45    3.068051   .6154871 |
//      +------------------------------+

// %% [markdown]
// We can see that at low work hours chosen, specifically up to 30 hours, the labor supply is very elastic with values above 1. It is very elastic also for 40 hours while between 30 to 40 hours worked, the labor supply becomes much less elastic with values less than 1.

// %% [markdown]
// # Discussion
//
// There is no doubt leisure time and time spent at home is highly valued. The estimates found in this paper support that notion, despite the popular contrary belief that Americans live to work. However, to properly compare the estimated found in this paper to those found in prior literature, the authors must account for possible gaps between wages and marginal products, taxes, fixed costs of employment, and child-care costs.
//
// _Wages vs. Marginal Products:_
//  **[Q18]** workers' marginal products likely weakly exceed their wages, so estimates of $z$ based on marginal product are weakly smaller than those based on wages, $\tilde{z}$. In the monopsony framework, the percent difference between marginal product and wage is the inverse of the elasticity of labor supply to the firm. Assuming a high elasticity of around 4, which is in line with Manning's estimates from 2011, MP will be 25% higher than wage, which indicates $z$ will be 20% *lower* than $\tilde{z}$.
//
// _Taxes:_
// $z$ is estimated using after-tax marginal product. Applying an effective tax rate of 0.2 increases the estimate of $z$ by 25%.
//
// _Fixed Costs of Employment (commuting and forgone benefits):_
// Assuming the average worker spends approximately one hour a day commuting, this would add 0.06 to the estimated value of $z$.
// As far as forgone benefits, there was no significant change in $z$ to be found because unemployed applicants often are not receiving Unemployment Insurance benefits, despite being eligible.

// %% [markdown]
// ***Table 3*** discusses the $\tilde z$ value for those potentially eligible for Unemployment Benefits, those who are not eligible, and those who may have childcare expenditures. The latter category is divided into three age groups:  Age 25 or younger , Age 26–39 , and Age 40 or older. The code-chunk below estimates $\tilde{z}$ for these 5 categories using the specification discussed above.

// %%
* Table 3_part 1

qui {
use experiment if emp_emp == 0 & chose_long < ., clear
mat T3 = J(3,6,.)
  local  col =1
gen ageg1 = 1 if agegroup == "25 and Under"
gen ageg2 = 1 if agegroup == "26-39"
gen ageg3 = 1 if agegroup == "40 and Above"

gen elig = 1 if ui_eligible == 1
gen inel = 1 if ui_eligible == 0

foreach v in elig inel ageg1 ageg2 ageg3 {
preserve
keep if `v' == 1 & hours_high <= 40


if "`v'" == "elig" 	global basewage = 13.68197 
if "`v'" == "inel" 	global basewage = 14.52753
if "`v'" == "ageg1" global basewage = 10.5806
if "`v'" == "ageg2" global basewage = 14.40184
if "`v'" == "ageg3" global basewage = 17.79058

global allregs = ""
local row = 1
foreach hrs in 10 15 20 25 30 35 40 {
eststo lgt`hrs': logit chose_long effectivewage if hours_high == `hrs'
global allregs = "$allregs lgt`hrs'"
}

suest $allregs , vce(robust)
     
foreach hrs in 10 15 20 25 30 35 40 {
local w`hrs' = "(- [lgt`hrs'_chose_long]_cons / [lgt`hrs'_chose_long]effectivewage)"
}

local w5 = "((`w15' - `w10')/(12.5-7.5))*(2.5-7.5) + `w10'"
count
nlcom 5*(`w5' + `w10' + `w15' + `w20' + `w25' + `w30' + `w35' + `w40')/40/$basewage
    
mat b =r(b)
mat v = r(V)
mat T3[1, `col'] = b[1,1]
mat T3[2, `col'] = v[1,1]^.5 
mat T3[3, `col'] = e(N)
    local col= `col'+1
restore
}
}

// %% [markdown]
// For all of these 5 categories, sample sizes show total numbers of applicants in the subgroup who are included in the $\tilde{z}$ calculation and robust standard errors calculated using the delta method. Additionally, the authors present results from Understanding America Study where respondents were each asked to make multiple hypothetical choices. This is the final column of Table 3 called UAS which is done by running the code below. For this column the sample size is the total number of choices used to estimate $\tilde{z}$, comprised of 785 survey responses.

// %%
* Table 3_part 2
* UAS:
qui{
    
mat uas = J(2,2,.)
use uas.dta, clear
foreach hrs in 20 30 40 {
gen ewage`hrs' = wageperc * (hh`hrs') if hh`hrs' < .
}
logit chose_long hh* ewage* [pw=rel_weight], nocons vce(cluster uasid)

local row = 1
foreach hrs in 20 30 40 {
local W`hrs' = "(-_b[hh`hrs']) / _b[ewage`hrs']"
}

local W10 = "((`W30') + (`W20'))/2"
nlcom 10*(`W40' + `W30' + `W20' + `W10')/40

mat b =r(b)
mat v = r(V)
mat T3[1, `col'] = b[1,1]
mat T3[2, `col'] = v[1,1]^.5 
mat T3[3, `col'] = e(N)
}

// %%
* Table 3_part 3
*formating 
qui {
    mat def Table1=mvt
    local row = "Est_z_tilda SE Obs"
local col = "UI_elig UI_inelig 25_and_Under 26-39 40_and_Above UAS_hw"
mat rownames  T3= `row'
mat colnames T3 = `col'
}
mat list T3
// Out:
// . mat list T3
//
// T3[3,6]
//                   UI_elig     UI_inelig  25_and_Under         26-39
// Est_z_tilda     .57224479     .60832404     .74396903     .53492383
//          SE     .05017401     .10242593     .12525029     .06098713
//         Obs           644           251           279           419
//
//              40_and_Above        UAS_hw
// Est_z_tilda     .52527587     .60922332
//          SE     .10411651     .03307447
//         Obs           188          2354

// %% [markdown]
// It is possible that the author's estimates may not fully capture the value of reduced benefits from working, especially if those eligible for UI do not collect. Overall, the amount of individuals receiving UI is low. ***Table 3*** also shows that, on average, most individuals in the labor force do not have child care expenses. This conversation continues in the next section.

// %% [markdown]
// Child Care:
// Because only 30% of workers are likely to have children under 15 who require child care, and because only 35% of that group actually have child care expenditures, it is not a large enough expense to significantly affect the estimate of $z$.
//
// In sum:
// - In the monopsony case after taxes, the estimate of $\tilde{z} = 0.58$.
// - Adding commuting, forgone benefits, and childcare, $\tilde{z} = 0.72$.
// - Using the MPD model to estimate $\tilde{z}$ in the monopsony case, $\tilde{z} = 0.87$.
//
//
// Overall, it is found that labor supply is highly elastic at low hours of work, and that the labor supply is relatively inelastic at the intensive margin. In general, most people in the United States are wither unemployed, or work full time (40+ hours per week). There are relatively few part-time workers because intermediate hours are on the elastic part of the supply curve, which goes from more elastic to more inelastic. Thus, there is a limited wage range where working part-time hours is optimal for a worker.

// %% [markdown]
// # Conclusion and Assessment
//
// This paper successfully maps out the relationship of effective wage and labor supply to better understand how people value their non-work time. It was found that labor supply is elastic at low hours of work, and relatively inelastic for full-time+ positions (high hours of work). Because of this, there are few part time workers in the United States. A point we wish the authors would have expanded on is how this varying elasticity of labor supply affects the productivity and economic growth of a country. Another potential weakness of this study was the overwhelming proportion of women to men. Women often have very different career goals than men, and having a more diversified sample could potentially make for more interesting results. A strength of this paper, however, is the inclusion of the fixed costs of employment in the discussion section. These costs, specifically child-care and commuting, certainly affects how people allocate and prioritize their time. However, the section regarding childcare costs seems haste and does not mention where the estimates of childcare costs come from, which left us feeling as though this section, too, could be expanded on.
